# %%
import pandas as pd

# %%
df1 = pd.read_csv('df1')

# %%
df2 = pd.read_csv('df2')

# %%
df1.head()
# Out:
#    Unnamed: 0         A         B         C         D
# 0  2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 1  2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2  2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 3  2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 4  2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df2.head()
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008

# %%
df2.plot()
# Out:
# <Axes: >

# %%
df2.plot.area(alpha=0.9)
# Out:
# <Axes: >

# %%
df2.plot.bar()
# Out:
# <Axes: >

# %%
df1.plot.hist(bins=50)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df1.plot.hist(bins=10)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df1['A'].plot.hist(bins=50)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df1.plot.scatter(x='A',y='B')
# Out:
# <Axes: xlabel='A', ylabel='B'>

# %%
df1.plot.scatter('A','A')
# Out:
# <Axes: xlabel='A', ylabel='A'>

# %%
df2.plot.box()
# Out:
# <Axes: >

# %%
df1.plot().box()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 df1.plot().box()
#
# AttributeError: 'Axes' object has no attribute 'box'

# %%
df2.plot.hexbin(x='a',y='b',gridsize= 30, cmap='Oranges')
# Out:
# <Axes: xlabel='a', ylabel='b'>

# %%
df1.plot.hexbin(x='A',y='B',gridsize=25,cmap='Oranges')
# Out:
# <Axes: xlabel='A', ylabel='B'>
